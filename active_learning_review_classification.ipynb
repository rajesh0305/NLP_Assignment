# %% [markdown]
# <a href="https://colab.research.google.com/github/rajesh0305/NLP_Assignment/blob/main/active_learning_review_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review Classification using Active Learning
#
# **Author:** [Rajesh Kumar](www.linkedin.com/in/rajesh-kumar-564b8a188)<br>
# **Date created:** 2025/1/29<br>
# **Last modified:** 2024/02/08<br>
# **Description:** Demonstrating the advantages of active learning through review classification.

# %% [markdown]
# ## Introduction
#
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity
# amongst businesses and researchers. Active Learning seeks to progressively
# train ML models so that the resultant model requires lesser amount of training data to
# achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The
# oracle is an annotator that cleans, selects, labels the data, and feeds it to the model
# when required. The oracle is a trained individual or a group of individuals that
# ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an
# initial model. The best model checkpoint is saved and then tested on a balanced test
# set. The test set must be carefully sampled because the full training process will be
# dependent on it. Once we have the initial evaluation scores, the oracle is tasked with
# labeling more samples; the number of data points to be sampled is usually determined by
# the business requirements. After that, the newly sampled data is added to the training
# set, and the training procedure repeats. This cycle continues until either an
# acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by
# demonstrating a ratio-based (least confidence) sampling strategy that results in lower
# overall false positive and negative rates when compared to a model trained on the entire
# dataset. This sampling falls under the domain of *uncertainty sampling*, in which new
# datasets are sampled based on the uncertainty that the model outputs for the
# corresponding label. In our example, we compare our model's false positive and false
# negative rates and annotate the new data based on their ratio.
#
# Some other sampling techniques include:
#
# 1. [Committee sampling](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Using multiple models to vote for the best data points to be sampled
# 2. [Entropy reduction](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Sampling according to an entropy threshold, selecting more of the samples that produce the highest entropy score.
# 3. [Minimum margin based sampling](https://arxiv.org/abs/1906.00025v1):
# Selects data points closest to the decision boundary

# %% [markdown]
# ## Importing required libraries

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"  # @param ["tensorflow", "jax", "torch"]
import keras
from keras import ops
from keras import layers
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()

# %% [markdown]
# ## Loading and preprocessing the data
#
# We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000
# reviews in total, including training and testing splits. We will merge these splits and
# sample our own, balanced training, validation and testing sets.

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Total examples: 50000

# %% [markdown]
# Active learning starts with labeling a subset of data.
# For the ratio sampling technique that we will be using, we will need well-balanced training,
# validation and testing splits.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# ### Fitting the `TextVectorization` layer
#
# Since we are working with text data, we will need to encode the text strings as vectors which
# would then be passed through an `Embedding` layer. To make this tokenization process
# faster, we use the `map()` function with its parallelization functionality.

# %%
vectorizer = layers.TextVectorization(
    3000, standardize="lower_and_strip_punctuation", output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# ## Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Creating the Model
#
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure
# that the model architecture is capable of overfitting to the initial data.
# Overfitting gives a strong hint that the model will have enough capacity for
# future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model
#model.summary()

# %% [markdown]
# ## Training on the entire dataset
#
# To show the effectiveness of Active Learning, we will first train the model on the entire
# dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=50,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.keras", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.keras")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 150, 128)            │         384,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 150, 64)             │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_1               │ (None, 64)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20)                  │           1,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - binary_accuracy: 0.6297 - false_negatives_1: 1845.1538 - false_positives_1: 5635.2051 - loss: 0.6548
# Epoch 1: val_loss improved from inf to 0.61298, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 37ms/step - binary_accuracy: 0.6297 - false_negatives_1: 1893.8102 - false_positives_1: 5679.1646 - loss: 0.6547 - val_binary_accuracy: 0.6628 - val_false_negatives_1: 1502.0000 - val_false_positives_1: 184.0000 - val_loss: 0.6130
# Epoch 2/50
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.7423 - false_negatives_1: 1875.5161 - false_positives_1: 3124.2903 - loss: 0.5475
# Epoch 2: val_loss improved from 0.61298 to 0.43827, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - binary_accuracy: 0.7425 - false_negatives_1: 1918.4241 - false_positives_1: 3172.0063 - loss: 0.5471 - val_binary_accuracy: 0.7988 - val_false_negatives_1: 358.0000 - val_false_positives_1: 648.0000 - val_loss: 0.4383
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8123 - false_negatives_1: 1595.7007 - false_positives_1: 2239.1211 - loss: 0.4408
# Epoch 3: val_loss did not improve from 0.43827
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - binary_accuracy: 0.8123 - false_negatives_1: 1607.6772 - false_positives_1: 2250.9368 - loss: 0.4408 - val_binary_accuracy: 0.7926 - val_false_negatives_1: 865.0000 - val_false_positives_1: 172.0000 - val_loss: 0.4387
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8313 - false_negatives_1: 1551.6370 - false_positives_1: 1899.1720 - loss: 0.4007
# Epoch 4: val_loss improved from 0.43827 to 0.36403, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8313 - false_negatives_1: 1562.7405 - false_positives_1: 1909.4304 - loss: 0.4007 - val_binary_accuracy: 0.8448 - val_false_negatives_1: 471.0000 - val_false_positives_1: 305.0000 - val_loss: 0.3640
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8482 - false_negatives_1: 1421.1083 - false_positives_1: 1682.8662 - loss: 0.3644
# Epoch 5: val_loss did not improve from 0.36403
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - binary_accuracy: 0.8482 - false_negatives_1: 1431.1329 - false_positives_1: 1692.4050 - loss: 0.3644 - val_binary_accuracy: 0.8360 - val_false_negatives_1: 623.0000 - val_false_positives_1: 197.0000 - val_loss: 0.3700
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8584 - false_negatives_1: 1322.9172 - false_positives_1: 1545.4458 - loss: 0.3442
# Epoch 6: val_loss did not improve from 0.36403
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.8584 - false_negatives_1: 1332.1709 - false_positives_1: 1554.3102 - loss: 0.3443 - val_binary_accuracy: 0.8162 - val_false_negatives_1: 118.0000 - val_false_positives_1: 801.0000 - val_loss: 0.4151
# Epoch 7/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8673 - false_negatives_1: 1214.3077 - false_positives_1: 1481.1025 - loss: 0.3292
# Epoch 7: val_loss improved from 0.36403 to 0.32718, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8673 - false_negatives_1: 1231.2405 - false_positives_1: 1498.0000 - loss: 0.3292 - val_binary_accuracy: 0.8572 - val_false_negatives_1: 369.0000 - val_false_positives_1: 345.0000 - val_loss: 0.3272
# Epoch 8/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8743 - false_negatives_1: 1143.4551 - false_positives_1: 1393.2179 - loss: 0.3148
# Epoch 8: val_loss did not improve from 0.32718
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.8743 - false_negatives_1: 1160.2595 - false_positives_1: 1409.5950 - loss: 0.3148 - val_binary_accuracy: 0.8564 - val_false_negatives_1: 395.0000 - val_false_positives_1: 323.0000 - val_loss: 0.3293
# Epoch 9/50
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8877 - false_negatives_1: 1018.5613 - false_positives_1: 1274.9291 - loss: 0.2915
# Epoch 9: val_loss did not improve from 0.32718
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - binary_accuracy: 0.8876 - false_negatives_1: 1041.6962 - false_positives_1: 1298.7405 - loss: 0.2917 - val_binary_accuracy: 0.8404 - val_false_negatives_1: 599.0000 - val_false_positives_1: 199.0000 - val_loss: 0.3553
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8921 - false_negatives_1: 1032.4458 - false_positives_1: 1203.8153 - loss: 0.2808
# Epoch 10: val_loss did not improve from 0.32718
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.8920 - false_negatives_1: 1039.6962 - false_positives_1: 1211.1582 - loss: 0.2809 - val_binary_accuracy: 0.8486 - val_false_negatives_1: 550.0000 - val_false_positives_1: 207.0000 - val_loss: 0.3466
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8983 - false_negatives_1: 944.1783 - false_positives_1: 1163.7261 - loss: 0.2682
# Epoch 11: val_loss did not improve from 0.32718
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - binary_accuracy: 0.8983 - false_negatives_1: 951.0569 - false_positives_1: 1170.6772 - loss: 0.2683 - val_binary_accuracy: 0.8576 - val_false_negatives_1: 442.0000 - val_false_positives_1: 270.0000 - val_loss: 0.3329
# Epoch 11: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.852400004863739, 'false_negatives_1': 396.0, 'false_positives_1': 342.0, 'loss': 0.3371698558330536}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
#
# ![Active Learning](https://i.imgur.com/dmNKusp.png)
#
# The pipeline can be summarized in five parts:
#
# 1. Sample and annotate a small, balanced training dataset
# 2. Train the model on this small subset
# 3. Evaluate the model on a balanced testing set
# 4. If the model satisfies the business criteria, deploy it in a real time setting
# 5. If it doesn't pass the criteria, sample a few more samples according to the ratio of
# false positives and negatives, add them to the training set and repeat from step 2 till
# the model passes the tests or till all available data is exhausted.
#
# For the code below, we will perform sampling using the following formula:<br/>
#
# ![Ratio Sampling](https://i.imgur.com/LyZEiZL.png)
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be
# using model checkpointing and early stopping for this example. The `patience` parameter
# for Early Stopping can help minimize overfitting and the time required. We have set it
# `patience=4` for now but since the model is robust, we can increase the patience level if
# desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my
# experience working on Active Learning techniques, this helps the model probe the
# newly formed loss landscape. Even if the model fails to improve in the second iteration,
# we will still gain insight about the possible future false positive and negative rates.
# This will help us sample a better set in the next iteration where the model will have a
# greater chance to improve.

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.keras", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = ops.where(ops.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.keras")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ (None, 150, 128)            │         384,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ (None, 150, 64)             │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling1d_2               │ (None, 64)                  │               0 │
# │ (GlobalMaxPooling1D)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 20)                  │           1,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting to train with 15000 samples
# Epoch 1/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.5224 - false_negatives_2: 1578.7192 - false_positives_2: 1858.0702 - loss: 0.6906
# Epoch 1: val_loss improved from inf to 0.65835, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - binary_accuracy: 0.5245 - false_negatives_2: 1640.1000 - false_positives_2: 1949.5667 - loss: 0.6903 - val_binary_accuracy: 0.6864 - val_false_negatives_2: 420.0000 - val_false_positives_2: 1148.0000 - val_loss: 0.6584
# Epoch 2/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.6525 - false_negatives_2: 1081.1864 - false_positives_2: 1548.5424 - loss: 0.6457
# Epoch 2: val_loss improved from 0.65835 to 0.59584, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - binary_accuracy: 0.6528 - false_negatives_2: 1098.1666 - false_positives_2: 1570.3500 - loss: 0.6453 - val_binary_accuracy: 0.6702 - val_false_negatives_2: 141.0000 - val_false_positives_2: 1508.0000 - val_loss: 0.5958
# Epoch 3/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.7276 - false_negatives_2: 850.1896 - false_positives_2: 1179.1034 - loss: 0.5654
# Epoch 3: val_loss improved from 0.59584 to 0.50297, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - binary_accuracy: 0.7279 - false_negatives_2: 877.8500 - false_positives_2: 1215.4667 - loss: 0.5649 - val_binary_accuracy: 0.7536 - val_false_negatives_2: 277.0000 - val_false_positives_2: 955.0000 - val_loss: 0.5030
# Epoch 4/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7767 - false_negatives_2: 713.2414 - false_positives_2: 954.9310 - loss: 0.4978
# Epoch 4: val_loss improved from 0.50297 to 0.44465, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.7767 - false_negatives_2: 736.4667 - false_positives_2: 987.5333 - loss: 0.4978 - val_binary_accuracy: 0.8046 - val_false_negatives_2: 375.0000 - val_false_positives_2: 602.0000 - val_loss: 0.4446
# Epoch 5/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8022 - false_negatives_2: 657.8276 - false_positives_2: 847.0345 - loss: 0.4548
# Epoch 5: val_loss improved from 0.44465 to 0.40103, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.8022 - false_negatives_2: 678.9000 - false_positives_2: 874.3000 - loss: 0.4546 - val_binary_accuracy: 0.8252 - val_false_negatives_2: 395.0000 - val_false_positives_2: 479.0000 - val_loss: 0.4010
# Epoch 6/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8112 - false_negatives_2: 646.7414 - false_positives_2: 780.0172 - loss: 0.4422
# Epoch 6: val_loss improved from 0.40103 to 0.40009, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.8113 - false_negatives_2: 668.1500 - false_positives_2: 804.1500 - loss: 0.4420 - val_binary_accuracy: 0.8232 - val_false_negatives_2: 313.0000 - val_false_positives_2: 571.0000 - val_loss: 0.4001
# Epoch 7/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8335 - false_negatives_2: 602.2931 - false_positives_2: 667.3448 - loss: 0.3981
# Epoch 7: val_loss did not improve from 0.40009
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8335 - false_negatives_2: 621.7833 - false_positives_2: 688.9000 - loss: 0.3981 - val_binary_accuracy: 0.8158 - val_false_negatives_2: 678.0000 - val_false_positives_2: 243.0000 - val_loss: 0.4107
# Epoch 8/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8453 - false_negatives_2: 548.0862 - false_positives_2: 622.2414 - loss: 0.3812
# Epoch 8: val_loss improved from 0.40009 to 0.37025, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.8452 - false_negatives_2: 565.5833 - false_positives_2: 644.3333 - loss: 0.3814 - val_binary_accuracy: 0.8428 - val_false_negatives_2: 371.0000 - val_false_positives_2: 415.0000 - val_loss: 0.3703
# Epoch 9/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.8548 - false_negatives_2: 542.3898 - false_positives_2: 589.8135 - loss: 0.3651
# Epoch 9: val_loss did not improve from 0.37025
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - binary_accuracy: 0.8548 - false_negatives_2: 551.3500 - false_positives_2: 599.4333 - loss: 0.3651 - val_binary_accuracy: 0.8398 - val_false_negatives_2: 325.0000 - val_false_positives_2: 476.0000 - val_loss: 0.3717
# Epoch 10/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8636 - false_negatives_2: 487.7069 - false_positives_2: 540.2069 - loss: 0.3435
# Epoch 10: val_loss improved from 0.37025 to 0.36894, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8637 - false_negatives_2: 503.5167 - false_positives_2: 557.5000 - loss: 0.3433 - val_binary_accuracy: 0.8418 - val_false_negatives_2: 478.0000 - val_false_positives_2: 313.0000 - val_loss: 0.3689
# Epoch 11/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8626 - false_negatives_2: 482.5439 - false_positives_2: 507.3158 - loss: 0.3583
# Epoch 11: val_loss did not improve from 0.36894
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8628 - false_negatives_2: 507.0000 - false_positives_2: 532.7000 - loss: 0.3575 - val_binary_accuracy: 0.8352 - val_false_negatives_2: 245.0000 - val_false_positives_2: 579.0000 - val_loss: 0.3857
# Epoch 12/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8804 - false_negatives_2: 431.8103 - false_positives_2: 471.5690 - loss: 0.3112
# Epoch 12: val_loss did not improve from 0.36894
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.8804 - false_negatives_2: 446.4167 - false_positives_2: 486.7167 - loss: 0.3114 - val_binary_accuracy: 0.8170 - val_false_negatives_2: 184.0000 - val_false_positives_2: 731.0000 - val_loss: 0.4227
# Epoch 13/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8781 - false_negatives_2: 442.0517 - false_positives_2: 457.5690 - loss: 0.3084
# Epoch 13: val_loss did not improve from 0.36894
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - binary_accuracy: 0.8781 - false_negatives_2: 456.9500 - false_positives_2: 472.5500 - loss: 0.3084 - val_binary_accuracy: 0.8410 - val_false_negatives_2: 269.0000 - val_false_positives_2: 526.0000 - val_loss: 0.3751
# Epoch 14/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8947 - false_negatives_2: 385.1754 - false_positives_2: 424.7719 - loss: 0.2879
# Epoch 14: val_loss did not improve from 0.36894
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.8945 - false_negatives_2: 405.3833 - false_positives_2: 446.5333 - loss: 0.2881 - val_binary_accuracy: 0.8482 - val_false_negatives_2: 412.0000 - val_false_positives_2: 347.0000 - val_loss: 0.3735
# Epoch 14: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 440.0, Number of ones incorrectly classified: 351.0
# Sample ratio for positives: 0.44374209860935526, Sample ratio for negatives:0.5562579013906448
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8691 - false_negatives_3: 626.8052 - false_positives_3: 608.9221 - loss: 0.3429
# Epoch 1: val_loss did not improve from 0.36894
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - binary_accuracy: 0.8694 - false_negatives_3: 648.2375 - false_positives_3: 632.0875 - loss: 0.3420 - val_binary_accuracy: 0.8352 - val_false_negatives_3: 229.0000 - val_false_positives_3: 595.0000 - val_loss: 0.3855
# Epoch 2/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8957 - false_negatives_3: 533.0253 - false_positives_3: 547.6709 - loss: 0.2830
# Epoch 2: val_loss did not improve from 0.36894
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.8956 - false_negatives_3: 539.8500 - false_positives_3: 554.4500 - loss: 0.2832 - val_binary_accuracy: 0.8454 - val_false_negatives_3: 295.0000 - val_false_positives_3: 478.0000 - val_loss: 0.3692
# Epoch 3/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9011 - false_negatives_3: 515.6667 - false_positives_3: 515.6795 - loss: 0.2715
# Epoch 3: val_loss did not improve from 0.36894
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - binary_accuracy: 0.9010 - false_negatives_3: 528.5500 - false_positives_3: 528.7625 - loss: 0.2717 - val_binary_accuracy: 0.8366 - val_false_negatives_3: 509.0000 - val_false_positives_3: 308.0000 - val_loss: 0.3700
# Epoch 4/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9091 - false_negatives_3: 476.3333 - false_positives_3: 462.1154 - loss: 0.2540
# Epoch 4: val_loss did not improve from 0.36894
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - binary_accuracy: 0.9090 - false_negatives_3: 487.8500 - false_positives_3: 474.4125 - loss: 0.2542 - val_binary_accuracy: 0.8376 - val_false_negatives_3: 232.0000 - val_false_positives_3: 580.0000 - val_loss: 0.4162
# Epoch 5/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9076 - false_negatives_3: 471.6076 - false_positives_3: 468.0000 - loss: 0.2551
# Epoch 5: val_loss did not improve from 0.36894
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.9076 - false_negatives_3: 477.2375 - false_positives_3: 473.4875 - loss: 0.2551 - val_binary_accuracy: 0.8444 - val_false_negatives_3: 303.0000 - val_false_positives_3: 475.0000 - val_loss: 0.3855
# Epoch 6/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9210 - false_negatives_3: 417.2278 - false_positives_3: 404.9620 - loss: 0.2320
# Epoch 6: val_loss did not improve from 0.36894
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.9210 - false_negatives_3: 422.2750 - false_positives_3: 410.1250 - loss: 0.2321 - val_binary_accuracy: 0.8268 - val_false_negatives_3: 202.0000 - val_false_positives_3: 664.0000 - val_loss: 0.4295
# Epoch 6: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 523.0, Number of ones incorrectly classified: 318.0
# Sample ratio for positives: 0.37812128418549346, Sample ratio for negatives:0.6218787158145065
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - binary_accuracy: 0.8429 - false_negatives_4: 956.5773 - false_positives_4: 943.2474 - loss: 0.4032
# Epoch 1: val_loss did not improve from 0.36894
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - binary_accuracy: 0.8430 - false_negatives_4: 975.4343 - false_positives_4: 962.0303 - loss: 0.4027 - val_binary_accuracy: 0.8214 - val_false_negatives_4: 694.0000 - val_false_positives_4: 199.0000 - val_loss: 0.3865
# Epoch 2/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8606 - false_negatives_4: 890.3608 - false_positives_4: 848.4639 - loss: 0.3433
# Epoch 2: val_loss improved from 0.36894 to 0.34924, saving model to AL_Model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - binary_accuracy: 0.8606 - false_negatives_4: 907.6061 - false_positives_4: 865.4243 - loss: 0.3432 - val_binary_accuracy: 0.8482 - val_false_negatives_4: 361.0000 - val_false_positives_4: 398.0000 - val_loss: 0.3492
# Epoch 3/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8766 - false_negatives_4: 804.4583 - false_positives_4: 746.6979 - loss: 0.3230
# Epoch 3: val_loss did not improve from 0.34924
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.8765 - false_negatives_4: 829.0000 - false_positives_4: 769.9293 - loss: 0.3230 - val_binary_accuracy: 0.8204 - val_false_negatives_4: 155.0000 - val_false_positives_4: 743.0000 - val_loss: 0.4094
# Epoch 4/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8782 - false_negatives_4: 781.2578 - false_positives_4: 743.6495 - loss: 0.3152
# Epoch 4: val_loss improved from 0.34924 to 0.34670, saving model to AL_Model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - binary_accuracy: 0.8782 - false_negatives_4: 796.8081 - false_positives_4: 758.6061 - loss: 0.3152 - val_binary_accuracy: 0.8486 - val_false_negatives_4: 419.0000 - val_false_positives_4: 338.0000 - val_loss: 0.3467
# Epoch 5/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8890 - false_negatives_4: 719.3062 - false_positives_4: 699.4694 - loss: 0.2876
# Epoch 5: val_loss did not improve from 0.34670
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - binary_accuracy: 0.8890 - false_negatives_4: 726.7374 - false_positives_4: 706.2020 - loss: 0.2877 - val_binary_accuracy: 0.8186 - val_false_negatives_4: 151.0000 - val_false_positives_4: 756.0000 - val_loss: 0.4238
# Epoch 6/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8918 - false_negatives_4: 665.5833 - false_positives_4: 655.8750 - loss: 0.2853
# Epoch 6: val_loss did not improve from 0.34670
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - binary_accuracy: 0.8918 - false_negatives_4: 686.3131 - false_positives_4: 675.9394 - loss: 0.2853 - val_binary_accuracy: 0.8422 - val_false_negatives_4: 503.0000 - val_false_positives_4: 286.0000 - val_loss: 0.3563
# Epoch 7/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9044 - false_negatives_4: 634.8265 - false_positives_4: 588.6021 - loss: 0.2678
# Epoch 7: val_loss did not improve from 0.34670
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - binary_accuracy: 0.9043 - false_negatives_4: 641.4141 - false_positives_4: 594.5657 - loss: 0.2678 - val_binary_accuracy: 0.8490 - val_false_negatives_4: 397.0000 - val_false_positives_4: 358.0000 - val_loss: 0.3539
# Epoch 8/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9096 - false_negatives_4: 585.8660 - false_positives_4: 549.8763 - loss: 0.2526
# Epoch 8: val_loss did not improve from 0.34670
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.9096 - false_negatives_4: 598.0707 - false_positives_4: 560.6667 - loss: 0.2526 - val_binary_accuracy: 0.8392 - val_false_negatives_4: 230.0000 - val_false_positives_4: 574.0000 - val_loss: 0.3941
# Epoch 8: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 436.0, Number of ones incorrectly classified: 341.0
# Sample ratio for positives: 0.43886743886743884, Sample ratio for negatives:0.5611325611325612
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - binary_accuracy: 0.8729 - false_negatives_5: 966.9661 - false_positives_5: 929.3305 - loss: 0.3370
# Epoch 1: val_loss did not improve from 0.34670
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - binary_accuracy: 0.8729 - false_negatives_5: 974.7983 - false_positives_5: 936.9328 - loss: 0.3368 - val_binary_accuracy: 0.8516 - val_false_negatives_5: 291.0000 - val_false_positives_5: 451.0000 - val_loss: 0.3479
# Epoch 2/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8948 - false_negatives_5: 851.8975 - false_positives_5: 807.7949 - loss: 0.2811
# Epoch 2: val_loss did not improve from 0.34670
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.8946 - false_negatives_5: 866.9244 - false_positives_5: 822.0840 - loss: 0.2814 - val_binary_accuracy: 0.8260 - val_false_negatives_5: 156.0000 - val_false_positives_5: 714.0000 - val_loss: 0.3957
# Epoch 3/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9030 - false_negatives_5: 766.3077 - false_positives_5: 758.8376 - loss: 0.2638
# Epoch 3: val_loss improved from 0.34670 to 0.34354, saving model to AL_Model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - binary_accuracy: 0.9028 - false_negatives_5: 780.5042 - false_positives_5: 772.3865 - loss: 0.2640 - val_binary_accuracy: 0.8524 - val_false_negatives_5: 343.0000 - val_false_positives_5: 395.0000 - val_loss: 0.3435
# Epoch 4/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9085 - false_negatives_5: 751.1695 - false_positives_5: 689.7542 - loss: 0.2641
# Epoch 4: val_loss did not improve from 0.34354
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - binary_accuracy: 0.9084 - false_negatives_5: 757.8235 - false_positives_5: 695.7899 - loss: 0.2641 - val_binary_accuracy: 0.8490 - val_false_negatives_5: 452.0000 - val_false_positives_5: 303.0000 - val_loss: 0.3549
# Epoch 5/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9112 - false_negatives_5: 684.0513 - false_positives_5: 655.8376 - loss: 0.2487
# Epoch 5: val_loss did not improve from 0.34354
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - binary_accuracy: 0.9112 - false_negatives_5: 696.1512 - false_positives_5: 667.3026 - loss: 0.2488 - val_binary_accuracy: 0.8212 - val_false_negatives_5: 719.0000 - val_false_positives_5: 175.0000 - val_loss: 0.4095
# Epoch 6/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9204 - false_negatives_5: 652.1187 - false_positives_5: 571.2203 - loss: 0.2320
# Epoch 6: val_loss did not improve from 0.34354
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - binary_accuracy: 0.9204 - false_negatives_5: 657.7143 - false_positives_5: 576.4202 - loss: 0.2320 - val_binary_accuracy: 0.8516 - val_false_negatives_5: 312.0000 - val_false_positives_5: 430.0000 - val_loss: 0.3664
# Epoch 7/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9290 - false_negatives_5: 596.3135 - false_positives_5: 542.2627 - loss: 0.2142
# Epoch 7: val_loss did not improve from 0.34354
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - binary_accuracy: 0.9289 - false_negatives_5: 601.5883 - false_positives_5: 547.2269 - loss: 0.2143 - val_binary_accuracy: 0.8432 - val_false_negatives_5: 487.0000 - val_false_positives_5: 297.0000 - val_loss: 0.3716
# Epoch 7: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8510000109672546, 'false_negatives_5': 351.0, 'false_positives_5': 394.0, 'loss': 0.3454083502292633}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusion
#
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency
# benefits of using Active Learning, as it eliminates the need to annotate large amounts of
# data, saving resources.
#
# The following are some noteworthy observations from this example:
#
# 1. We only require 30,000 samples to reach the same (if not better) scores as the model
# trained on the full dataset. This means that in a real life setting, we save the effort
# required for annotating 10,000 images!
# 2. The number of false negatives and false positives are well balanced at the end of the
# training as compared to the skewed ratio obtained from the full training. This makes the
# model slightly more useful in real life scenarios where both the labels hold equal
# importance.
#
# For further reading about the types of sampling ratios, training techniques or available
# open source libraries/implementations, you can refer to the resources below:
#
# 1. [Active Learning Literature Survey](http://burrsettles.com/pub/settles.activelearning.pdf) (Burr Settles, 2010).
# 2. [modAL](https://github.com/modAL-python/modAL): A Modular Active Learning framework.
# 3. Google's unofficial [Active Learning playground](https://github.com/google/active-learning).
